#  -5117.6868588  -4612.12982549 -5783.5260973  -4690.28829984
#             nan            nan -5622.67956108 -5137.96721311
#  -5252.13635643 -5060.05668958            nan            nan
#  -6712.51386832 -5859.79937864 -6993.64118191 -6194.31368324
#             nan            nan -6884.53946325 -7253.44201481
#  -6288.8202935  -6583.4847303             nan            nan
#  -7610.12083554 -6547.02612374 -6829.95145426 -6887.2117927
#             nan            nan -7072.99301957 -6656.12971973
#  -6553.68773136 -6939.08836594]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 3,
#  'max_features': 'log2',
#  'splitter': 'random'}

# %%
y_pred=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print('R2 score:',r2_score(y_test,y_pred))
print('Mean Absolute Error:',mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.1775264978622988
# Mean Absolute Error: 60.454603952160355
# Mean Squared Error: 5204.341805905492

# %%
selectedmodel=DecisionTreeRegressor(criterion='squared_error',max_depth=4,max_features='sqrt',splitter='random')

# %%
selectedmodel.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, max_features='sqrt', splitter='random')

# %%
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(selectedmodel,filled=True)
# Out:
# [Text(0.5, 0.9, 'x[2] <= 0.009\nsquared_error = 5757.456\nsamples = 309\nvalue = 152.738'),
#  Text(0.25, 0.7, 'x[6] <= 0.023\nsquared_error = 3748.346\nsamples = 194\nvalue = 123.763'),
#  Text(0.375, 0.8, 'True  '),
#  Text(0.125, 0.5, 'x[0] <= -0.049\nsquared_error = 4147.309\nsamples = 126\nvalue = 138.31'),
#  Text(0.0625, 0.3, 'x[8] <= -0.044\nsquared_error = 3498.905\nsamples = 33\nvalue = 128.394'),
#  Text(0.03125, 0.1, 'squared_error = 1774.917\nsamples = 12\nvalue = 89.5'),
#  Text(0.09375, 0.1, 'squared_error = 3125.664\nsamples = 21\nvalue = 150.619'),
#  Text(0.1875, 0.3, 'x[7] <= 0.029\nsquared_error = 4330.121\nsamples = 93\nvalue = 141.828'),
#  Text(0.15625, 0.1, 'squared_error = 3066.746\nsamples = 52\nvalue = 116.846'),
#  Text(0.21875, 0.1, 'squared_error = 4137.03\nsamples = 41\nvalue = 173.512'),
#  Text(0.375, 0.5, 'x[5] <= -0.049\nsquared_error = 1890.478\nsamples = 68\nvalue = 96.809'),
#  Text(0.3125, 0.3, 'x[0] <= 0.032\nsquared_error = 3725.438\nsamples = 16\nvalue = 107.25'),
#  Text(0.28125, 0.1, 'squared_error = 1479.883\nsamples = 14\nvalue = 90.214'),
#  Text(0.34375, 0.1, 'squared_error = 3192.25\nsamples = 2\nvalue = 226.5'),
#  Text(0.4375, 0.3, 'x[4] <= -0.038\nsquared_error = 1282.01\nsamples = 52\nvalue = 93.596'),
#  Text(0.40625, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 182.0'),
#  Text(0.46875, 0.1, 'squared_error = 1150.903\nsamples = 51\nvalue = 91.863'),
#  Text(0.75, 0.7, 'x[9] <= -0.025\nsquared_error = 5341.245\nsamples = 115\nvalue = 201.617'),
#  Text(0.625, 0.8, '  False'),
#  Text(0.625, 0.5, 'x[8] <= 0.035\nsquared_error = 4489.55\nsamples = 20\nvalue = 155.5'),
#  Text(0.5625, 0.3, 'x[6] <= -0.063\nsquared_error = 3784.0\nsamples = 14\nvalue = 148.0'),
#  Text(0.53125, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.59375, 0.1, 'squared_error = 3558.071\nsamples = 13\nvalue = 154.077'),
#  Text(0.6875, 0.3, 'x[7] <= 0.047\nsquared_error = 5698.333\nsamples = 6\nvalue = 173.0'),
#  Text(0.65625, 0.1, 'squared_error = 4224.688\nsamples = 4\nvalue = 208.25'),
#  Text(0.71875, 0.1, 'squared_error = 1190.25\nsamples = 2\nvalue = 102.5'),
#  Text(0.875, 0.5, 'x[2] <= 0.102\nsquared_error = 4978.536\nsamples = 95\nvalue = 211.326'),
#  Text(0.8125, 0.3, 'x[3] <= -0.043\nsquared_error = 4560.899\nsamples = 88\nvalue = 204.398'),
#  Text(0.78125, 0.1, 'squared_error = 5438.444\nsamples = 9\nvalue = 152.0'),
#  Text(0.84375, 0.1, 'squared_error = 4112.511\nsamples = 79\nvalue = 210.367'),
#  Text(0.9375, 0.3, 'x[7] <= 0.092\nsquared_error = 2038.531\nsamples = 7\nvalue = 298.429'),
#  Text(0.90625, 0.1, 'squared_error = 2025.889\nsamples = 6\nvalue = 291.333'),
#  Text(0.96875, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 341.0')]
